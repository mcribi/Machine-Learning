# %% [markdown]
# # **Asignatura**: Aprendizaje Automático
#
# **Proyecto Práctico Opcional**: Aprendizaje por Refuerzo
#
# **Valoración máxima**: 10 puntos
#
# **Fecha límite de entrega**: 30 de Mayo de 2025 a las 23:59
#
# **Procedimiento de entrega**: a través de PRADO
#
#
# <font color="blue">**Trabajo grupal (máximo 2 componentes)**</font>
#
#
# ### Nombre completo 1: <mark>POR FAVOR, ESCRIBA AQUÍ SU NOMBRE</mark>
# ### Nombre completo 2: <mark>POR FAVOR, ESCRIBA AQUÍ SU NOMBRE</mark>

# %% [markdown]
# **Normas de desarrollo y entrega de trabajos**
#
# - Única y exclusivamente se debe entregar este Notebook de Colab (fichero `.ipynb`). **No es necesario entregar ninguna memoria externa** (por ejemplo, en `.pdf`).
#
# - El código debe estar bien comentado (explicando lo que realizan los distintos apartados y/o bloques), y todas las decisiones tomadas y el trabajo desarrollado (incluyendo los conceptos fundamentales subyacentes) deben documentarse ampliamente en celdas de texto. Es obligatorio documentar las valoraciones y decisiones adoptadas en el desarrollo de cada uno de los apartados. Debe incluirse también tanto una descripción de las principales funciones (Python/scikit-learn) empleadas (para mostrar que el alumno comprende, a nivel técnico, lo que está haciendo), como una valoración razonada sobre la calidad de los resultados obtenidos. **Sin esta documentación, se considera que el trabajo NO ha sido presentado**.
#
# - La entrega en PRADO está configurada para permitir sucesivas entregas de la práctica. Desde este punto de vista, se recomienda subir versiones de la práctica a medida que se van realizando los distintos ejercicios propuestos, y no dejarlo todo para el final.
#
# - Se debe respetar la estructura y secciones del Notebook. Esto servirá para agilizar las correcciones, así como para identificar con facilidad qué ejercicio/apartado se está respondiendo.
#
# - El código **NO debe escribir nada a disco**.
#
# - El **path de lectura desde Google Drive debe ser siempre el mismo**, que es el que se indica en este Notebook.
#
# - Una entrega es apta para ser corregida si se puede ejecutar de principio a fin sin errores. Es decir, un ejercicio con errores de ejecución tendrá una calificación de 0.
#
# - No es válido usar opciones en las entradas (es decir, utilizar el comando `input()`, por ejemplo, para que el usuario escoja el valor de las variables para ejecutar el programa). Para ello, se deben fijar al comienzo los valores
# por defecto que se consideren óptimos o que se soliciten en el enunciado.
#
# - Se entrega solamente este Notebook, y no los datos empleados.
#
#
# <font color="red"><b>SOBRE TODO, PENSAD EN SI ALGUIEN QUE NO HUBIERA VISTO VUESTRO TRABAJO SERÍA CAPAZ DE ENTENDER LO QUE HABÉIS ESCRITO Y HECHO, Y SI SERÍA CAPAZ DE VALORAR SU CONTENIDO</b></font>.
#
#
#
# A modo orientativo, las siguientes referencias podrían utilizarse inicialmente para responder a algunas de las cuestiones planteadas a lo largo del cuaderno:
#
# - <a href="https://www.andrew.cmu.edu/course/10-703/textbook/BartoSutton.pdf">https://www.andrew.cmu.edu/course/10-703/textbook/BartoSutton.pdf</a>
#
# - <a href="https://aws.amazon.com/es/what-is/reinforcement-learning/">https://aws.amazon.com/es/what-is/reinforcement-learning/</a>
#
# - <a href="https://www.datacamp.com/es/tutorial/reinforcement-learning-python-introduction">https://www.datacamp.com/es/tutorial/reinforcement-learning-python-introduction</a>
#
# - <a href="https://www.freecodecamp.org/espanol/news/introduccion-a-q-learning-aprendizaje-por-refuerzo/">https://www.freecodecamp.org/espanol/news/introduccion-a-q-learning-aprendizaje-por-refuerzo/</a>
#
# - <a href="https://openaccess.uoc.edu/bitstream/10609/151792/1/IntroduccionAlAprendizajePorRefuerzo.pdf">https://openaccess.uoc.edu/bitstream/10609/151792/1/IntroduccionAlAprendizajePorRefuerzo.pdf</a>
#
# - <a href="https://www.ibm.com/es-es/topics/reinforcement-learning">https://www.ibm.com/es-es/topics/reinforcement-learning</a>
#
# - <a href="https://www.researchgate.net/publication/335112487_Introduccion_al_Aprendizaje_por_Refuerzo">https://www.researchgate.net/publication/335112487_Introduccion_al_Aprendizaje_por_Refuerzo</a>
#
# - <a href="https://www.geeksforgeeks.org/reinforce-algorithm/">https://www.geeksforgeeks.org/reinforce-algorithm/</a>
#
# - <a href="https://dilithjay.com/blog/reinforce-a-quick-introduction-with-code">https://dilithjay.com/blog/reinforce-a-quick-introduction-with-code</a>

# %% [markdown]
# # **¿Qué es el aprendizaje por refuerzo? (2 punto)**

# %% [markdown]
# Realizad una búsqueda bibliográfica sobre qué es el aprendizaje por refuerzo en *Machine Learning*.
#
# A continuación, describid qué es el aprendizaje por refuerzo (usad vuestras propias palabras, **NO ESTÁ PERMITIDO** el uso de IA Generativa para realizar este apartado).
#
# En particular, el texto escrito debe contener información que pueda responder a las siguientes preguntas:
#
# - ¿Dónde se encuadra el aprendizaje por refuerzo dentro del aprendizaje automático?
# - ¿Qué dos elementos principales hay involucrados en el aprendizaje por refuerzo?
# - ¿Cuál es el ciclo de interacción entre el agente y el entorno?
# - ¿Qué es un agente? ¿Qué es un entorno?
# - Conceptos descriptivos sobre qué es:
#    - Un estado y el espacio de estados.
#    - Una acción y el espacio de acciones.
#    - Una recompensa.
#    - Una política. Distinga entre políticas deterministas y no deterministas.
#    - Una experiencia.
#    - Un episodio y una trayectoria. Diferencias entre ambos.
# - ¿Cuál es la estructura subyacente que se supone que tiene un entorno? Ponga un ejemplo de Proceso de Decisión de Markov sencillo con pocos estados y acciones.
# - ¿Cuál es el objetivo de un agente en el aprendizaje por refuerzo?
#    - Concepto de retorno (Return).
#    - Concepto de factor de descuento $\gamma$, para qué se usa y su influencia en el valor de retorno con valores altos o bajos.
# - ¿Qué es el valor de un estado $V(s)$?
# - ¿Qué es el valor de un par estado-acción $Q(s,a)$?
#
#
# Para responder a estas preguntas puede utilizar cualquier fuente bibliográfica, sea un libro, documento o web. Recuerde **citar las fuentes apropiadamente**.
#
#
# En términos generales: <font color="red">se persigue que el estudiante elabore unos <i>mini-apuntes</i> que le permitan estudiar y aprender qué es el aprendizaje por refuerzo, a nivel introductorio.</font>

# %% [markdown]
# # **Aprendizaje por refuerzo clásico (4 puntos)**

# %% [markdown]
# ## La biblioteca *Gymnasium*

# %% [markdown]
# Su web principal es <a href="https://gymnasium.farama.org/index.html">https://gymnasium.farama.org/index.html</a>
#
# - Busque información sobre la biblioteca Gymnasium e instálela.
# - Instancie la biblioteca con el entorno ```'CliffWalking-v0'```. Describa, para el entorno generado...:
#   - Cuál es el espacio de estados.
#   . Cuál es el espacio de acciones.
#   - Cuál es el sistema de recompensas.
#   - Cuál es el sistema de terminación/parada de un episodio.
#   - Para qué sirve el método **reset()**, qué entradas tiene y qué salidas proporciona y qué información contienen las salidas.
#   - Para qué sirve el método **step()**, qué entradas tiene y qué salidas proporciona, describiendo el significado de cada una de ellas.

# %% [markdown]
# Implemente de forma manual dos políticas, haciendo uso del **wrapper** *TimeLimit* para limitar el número de experiencias en un episodio a 500:
#
# - Una función que implemente una política aleatoria.
# - Una función que implemente una política óptima.
#
# Además:
#
# - Ejecute ambas políticas un total de 100 episodios y compare, analice y discuta los resultados obtenidos.
# - Utilice el parámetro **render** para obtener una visualización de un único episodio con cada política. En caso de obtener algún error de ejecución: <a href="https://stackoverflow.com/questions/50107530/how-to-render-openai-gym-in-google-colab">Stack Overflow</a> y similares.

# %% [markdown]
# ## Algoritmos clásicos

# %% [markdown]
# - Busque información de algoritmos clásicos de Aprendizaje por Refuerzo (Q-Learning, SARSA, Value Iteration, Policy Iteration, ...).
# - Seleccione uno de ellos.
# - Describa su funcionamiento a nivel general, pero con rigor (pasos del algoritmo, función de actualización y qué significa cada término, etc.).
#
# En términos generales: <font color="red">se debe describir qué métodos existen desde antes de la incursión de Deep Learning para aprendizaje por refuerzo dando una visión general del área, seleccionar uno de los métodos de aprendizaje y explicarlo en detalle.</font>

# %% [markdown]
# ### Implementación

# %% [markdown]
# - Implemente desde cero el algoritmo seleccionado.
# - Describa su funcionamiento (pasos del algoritmo, función de actualización y qué significa cada término, etc.) **y su relación con la descripción general dada en el apartado anterior**.
# - Aplíquelo sobre algún entorno de la biblioteca Gymnasium, justificando su idoneidad en términos de espacios de estados y acciones, diseño de recompensas, etc.. Justifique también el uso de hiperparámetros (de haberlos). No olvide también describir el entorno seleccionado (espacio de estados, espacio de acciones, recompensas, etc.)
# - Discuta los resultados obtenidos considerando el número de veces que el entorno ha sido resuelto tras 100 ejecuciones distintas de prueba de la política obtenida con el algoritmo. Si procede, también puede comparar su implementación con la tabla de clasificación dada en <a href="https://github.com/openai/gym/wiki/Leaderboard">https://github.com/openai/gym/wiki/Leaderboard</a>.
#
# En términos generales: <font color="red">se debe usar el algoritmo implementado para resolver un problema, y describir los pasos seguidos con detalle enlazando la implementación con la parte teórica.</font>

# %% [markdown]
# # **Aprendizaje por refuerzo profundo (4 puntos)**

# %% [markdown]
# - Busque información sobre algoritmos de **Deep Reinforcement Learning** y describa sus fundamentos, en términos globales/generales. En particular, interesa distinguir entre las categorías básicas derivadas de **Deep Q-Networks** y **Policy Gradient**.
#
# - Seleccione un algoritmo entre ellos. Se recomienda escoger alguno "tradicional" dentro del área de **Deep Reinforcement Learning**.
#
# - Describa el funcionamiento general del algoritmo, con sus propias palabras pero con rigor. En particular, interesa la descripción del algoritmo, sus componentes, funcionamiento y entrenamiento de la red de política, etc.. No olvide, especialmente, describir cómo se genera el conjunto de datos de entrada y salida, cuál es la función de pérdida a usar y cómo se efectúa el entrenamiento en cada iteración. **La descripción del algoritmo debe ser general, pero suficientemente detallada como para poder ser implementado tras leer dicha descripción**.
#
# En términos generales: <font color="red">se debe describir qué es el aprendizaje por refuerzo profundo dando una visión general del área, seleccionar uno de los métodos de aprendizaje y explicarlo en detalle.</font>

# %% [markdown]
# ## La biblioteca de programación

# %% [markdown]
# - Estudie las bibliotecas de programación de aprendizaje por refuerzo <a href="https://github.com/tensorflow/agents">TF-Agents</a> y <a href="https://github.com/keiohta/tf2rl">TF2-RL</a>. Trate de hallar ventajas e inconvenientes de cada una de ellas.
#
# - Seleccione alguna de las bibliotecas anteriores que contenga el algoritmo seleccionado en el apartado anterior.
#
# - Escoja un entorno de la biblioteca *Gymnasium* (distinto del usado anteriormente), entre los dados en las categorías **Toy Text** o **Classic Control**. No olvide también describir el entorno seleccionado (espacio de estados, espacio de acciones, recompensas, etc.)
#
# - Implemente una solución de **Deep Reinforcement Learning** para resolver el problema del entorno seleccionado, utilizando la biblioteca de aprendizaje por refuerzo para Tensorflow escogida.
#
# - Describa el uso de la biblioteca de aprendizaje para la resolución del problema (funciones y clases para implementar el algoritmo de aprendizaje y las políticas -y otras redes de ser requeridas por su método escogido-, componentes, parámetros e hiperparámetros...).
#
# - Indique cómo se adapta el uso de la biblioteca a la descripción general del algoritmo dada en el apartado anterior (se trata de enlazar la teoría previamente descrita con la práctica en el uso de la biblioteca seleccionada).
#
# - Discuta los resultados obtenidos considerando el número de veces que el entorno ha sido resuelto tras 100 ejecuciones distintas de prueba de la política obtenida con el algoritmo. Si procede, también puede comparar su implementación con la tabla de clasificación dada en <a href="https://github.com/openai/gym/wiki/Leaderboard">https://github.com/openai/gym/wiki/Leaderboard</a>.
#
#
# En términos generales: <font color="red">se debe usar la biblioteca seleccionada para resolver un problema con el método de aprendizaje escogido, y describir los pasos seguidos con detalle enlazando la implementación con la parte teórica.</font>

# %%
# !pip install gymnasium #ya instalada

# !pip install --upgrade pip setuptools wheel
# !pip install tensorflow
# !pip install gymnasium
# !pip install numpy
# !pip install typing-extensions

# !pip install --upgrade tensorflow tensorflow-probability
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.1.1-py3-none-any.whl (965 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.1.1
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.12.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0)
# ERROR: No matching distribution found for tensorflow==2.12.0
# Requirement already satisfied: pip in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (24.0)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (72.1.0)
# Collecting setuptools
#   Downloading setuptools-80.7.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (0.43.0)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.1 MB/s eta 0:00:00a 0:00:01
# Downloading setuptools-80.7.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.7 MB/s eta 0:00:0000:01
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.43.0
#     Uninstalling wheel-0.43.0:
#       Successfully uninstalled wheel-0.43.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 72.1.0
#     Uninstalling setuptools-72.1.0:
#       Successfully uninstalled setuptools-72.1.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.1.1 setuptools-80.7.1 wheel-0.45.1
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.12.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0)
# ERROR: No matching distribution found for tensorflow==2.12.0
# Collecting gymnasium==0.29.0
#   Downloading gymnasium-0.29.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium==0.29.0) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium==0.29.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium==0.29.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from gymnasium==0.29.0) (0.0.4)
# Downloading gymnasium-0.29.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.8/953.8 kB 3.1 MB/s eta 0:00:00-:--:--
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
# Successfully installed gymnasium-0.29.0
# Collecting numpy==1.24.0
#   Downloading numpy-1.24.0.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 21.1 MB/s eta 0:00:00 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       Traceback (most recent call last):
#         File "/home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#         File "/home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 137, in get_requires_for_build_wheel
#           backend = _build_backend()
#                     ^^^^^^^^^^^^^^^^
#         File "/home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 70, in _build_backend
#           obj = import_module(mod_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/importlib/__init__.py", line 90, in import_module
#           return _bootstrap._gcd_import(name[level:], package, level)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#         File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "/tmp/pip-build-env-2brq97l8/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 16, in <module>
#           import setuptools.version
#         File "/tmp/pip-build-env-2brq97l8/overlay/lib/python3.12/site-packages/setuptools/version.py", line 1, in <module>
#           import pkg_resources
#         File "/tmp/pip-build-env-2brq97l8/overlay/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2172, in <module>
#           register_finder(pkgutil.ImpImporter, find_on_path)
#                           ^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting typing-extensions==4.6.0
#   Downloading typing_extensions-4.6.0-py3-none-any.whl.metadata (2.8 kB)
# Downloading typing_extensions-4.6.0-py3-none-any.whl (30 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0 requires typing-extensions>=4.10.0, but you have typing-extensions 4.6.0 which is incompatible.
# nni 3.0 requires typing-extensions>=4.7.0, but you have typing-extensions 4.6.0 which is incompatible.
# pydantic 2.10.6 requires typing-extensions>=4.12.2, but you have typing-extensions 4.6.0 which is incompatible.
# zarr 3.0.4 requires typing-extensions>=4.9, but you have typing-extensions 4.6.0 which is incompatible.
# graphene 3.4.3 requires typing-extensions<5,>=4.7.1, but you have typing-extensions 4.6.0 which is incompatible.
# alembic 1.15.1 requires typing-extensions>=4.12, but you have typing-extensions 4.6.0 which is incompatible.
# Successfully installed typing-extensions-4.6.0
# Collecting tf-agents==0.15.0
#   Downloading tf_agents-0.15.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: absl-py>=0.6.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (2.1.0)
# Requirement already satisfied: cloudpickle>=1.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (3.1.1)
# Collecting gin-config>=0.4.0 (from tf-agents==0.15.0)
#   Downloading gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gym<=0.23.0,>=0.17.0 (from tf-agents==0.15.0)
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 9.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.13.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (1.26.4)
# Requirement already satisfied: pillow in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (10.4.0)
# Requirement already satisfied: six>=1.10.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (5.29.3)
# Requirement already satisfied: wrapt>=1.11.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (1.17.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents==0.15.0) (4.6.0)
# Collecting pygame==2.1.0 (from tf-agents==0.15.0)
#   Downloading pygame-2.1.0.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 12.9 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#
#
#       WARNING, No "Setup" File Exists, Running "buildconfig/config.py"
#       Using UNIX configuration...
#
#
#       Hunting dependencies...
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/Compilation
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-r6_sa44g/pygame_f7ebcbdfe7dd49fe8ac1d5b937524b36/setup.py", line 388, in <module>
#           buildconfig.config.main(AUTO_CONFIG)
#         File "/tmp/pip-install-r6_sa44g/pygame_f7ebcbdfe7dd49fe8ac1d5b937524b36/buildconfig/config.py", line 234, in main
#           deps = CFG.main(**kwds)
#                  ^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-r6_sa44g/pygame_f7ebcbdfe7dd49fe8ac1d5b937524b36/buildconfig/config_unix.py", line 188, in main
#           DependencyProg('SDL', 'SDL_CONFIG', 'sdl2-config', '2.0', ['sdl']),
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-r6_sa44g/pygame_f7ebcbdfe7dd49fe8ac1d5b937524b36/buildconfig/config_unix.py", line 39, in __init__
#           self.ver = config[0].strip()
#                      ~~~~~~^^^
#       IndexError: list index out of range
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting tf-agents
#   Downloading tf_agents-0.19.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: absl-py>=0.6.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (2.1.0)
# Requirement already satisfied: cloudpickle>=1.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (3.1.1)
# Collecting gin-config>=0.4.0 (from tf-agents)
#   Using cached gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gym<=0.23.0,>=0.17.0 (from tf-agents)
#   Using cached gym-0.23.0.tar.gz (624 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (1.26.4)
# Requirement already satisfied: pillow in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (10.4.0)
# Requirement already satisfied: six>=1.10.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (5.29.3)
# Requirement already satisfied: wrapt>=1.11.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (1.17.2)
# Collecting typing-extensions==4.5.0 (from tf-agents)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pygame==2.1.3 (from tf-agents)
#   Downloading pygame-2.1.3.tar.gz (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 15.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#
#
#       WARNING, No "Setup" File Exists, Running "buildconfig/config.py"
#       Using UNIX configuration...
#
#
#       Hunting dependencies...
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/Compilation
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-ydtllh45/pygame_c6fea259a82f417fabe430e28eb7daee/setup.py", line 400, in <module>
#           buildconfig.config.main(AUTO_CONFIG)
#         File "/tmp/pip-install-ydtllh45/pygame_c6fea259a82f417fabe430e28eb7daee/buildconfig/config.py", line 231, in main
#           deps = CFG.main(**kwds, auto_config=auto)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-ydtllh45/pygame_c6fea259a82f417fabe430e28eb7daee/buildconfig/config_unix.py", line 218, in main
#           DependencyProg('SDL', 'SDL_CONFIG', 'sdl2-config', '2.0', ['sdl']),
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-ydtllh45/pygame_c6fea259a82f417fabe430e28eb7daee/buildconfig/config_unix.py", line 43, in __init__
#           self.ver = config[0].strip()
#                      ~~~~~~^^^
#       IndexError: list index out of range
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tensorflow-probability
#   Downloading tensorflow_probability-0.25.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (80.7.1)
# Requirement already satisfied: six>=1.12.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (4.6.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (2.19.0)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow) (3.13.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: decorator in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow-probability) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tensorflow-probability) (3.1.1)
# Collecting dm-tree (from tensorflow-probability)
#   Downloading dm_tree-0.1.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.9-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: attrs>=18.2.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from dm-tree->tensorflow-probability) (25.1.0)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (645.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 21.1 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 19.3 MB/s eta 0:00:00a 0:00:01
# Downloading tensorflow_probability-0.25.0-py2.py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 29.3 MB/s eta 0:00:00a 0:00:01
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.7 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 20.2 MB/s eta 0:00:0000:0100:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading dm_tree-0.1.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153 kB)
# Downloading namex-0.0.9-py3-none-any.whl (5.8 kB)
# Downloading optree-0.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (404 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, optree, opt-einsum, ml-dtypes, mdurl, google-pasta, gast, dm-tree, astunparse, tensorflow-probability, markdown-it-py, rich, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [tensorflow]6 [tensorflow]probability]
# Successfully installed astunparse-1.6.3 dm-tree-0.1.9 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 keras-3.9.2 libclang-18.1.1 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.9 opt-einsum-3.4.0 optree-0.15.0 rich-14.0.0 tensorflow-2.19.0 tensorflow-probability-0.25.0

# %%
# !pip install tf-agents
# Out:
# Collecting tf-agents
#   Using cached tf_agents-0.19.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: absl-py>=0.6.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (2.1.0)
# Requirement already satisfied: cloudpickle>=1.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (3.1.1)
# Collecting gin-config>=0.4.0 (from tf-agents)
#   Using cached gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gym<=0.23.0,>=0.17.0 (from tf-agents)
#   Using cached gym-0.23.0.tar.gz (624 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (1.26.4)
# Requirement already satisfied: pillow in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (10.4.0)
# Requirement already satisfied: six>=1.10.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (5.29.3)
# Requirement already satisfied: wrapt>=1.11.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents) (1.17.2)
# Collecting typing-extensions==4.5.0 (from tf-agents)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pygame==2.1.3 (from tf-agents)
#   Using cached pygame-2.1.3.tar.gz (12.8 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#
#
#       WARNING, No "Setup" File Exists, Running "buildconfig/config.py"
#       Using UNIX configuration...
#
#
#       Hunting dependencies...
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/Compilation
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-j1prbnq2/pygame_dcb478d28b9d46b7957bd92eabb12e21/setup.py", line 400, in <module>
#           buildconfig.config.main(AUTO_CONFIG)
#         File "/tmp/pip-install-j1prbnq2/pygame_dcb478d28b9d46b7957bd92eabb12e21/buildconfig/config.py", line 231, in main
#           deps = CFG.main(**kwds, auto_config=auto)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-j1prbnq2/pygame_dcb478d28b9d46b7957bd92eabb12e21/buildconfig/config_unix.py", line 218, in main
#           DependencyProg('SDL', 'SDL_CONFIG', 'sdl2-config', '2.0', ['sdl']),
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-j1prbnq2/pygame_dcb478d28b9d46b7957bd92eabb12e21/buildconfig/config_unix.py", line 43, in __init__
#           self.ver = config[0].strip()
#                      ~~~~~~^^^
#       IndexError: list index out of range
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install tf-agents[reverb]
# Out:
# Requirement already satisfied: pip in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (25.1.1)
# Requirement already satisfied: setuptools in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (80.7.1)
# Requirement already satisfied: wheel in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (0.45.1)
# Collecting tf-agents[reverb]
#   Using cached tf_agents-0.19.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: absl-py>=0.6.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (2.1.0)
# Requirement already satisfied: cloudpickle>=1.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (3.1.1)
# Collecting gin-config>=0.4.0 (from tf-agents[reverb])
#   Using cached gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gym<=0.23.0,>=0.17.0 (from tf-agents[reverb])
#   Using cached gym-0.23.0.tar.gz (624 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (1.26.4)
# Requirement already satisfied: pillow in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (10.4.0)
# Requirement already satisfied: six>=1.10.0 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (5.29.3)
# Requirement already satisfied: wrapt>=1.11.1 in /home/maria-cribilles/anaconda3/envs/tfg-maria-pruebas/lib/python3.12/site-packages (from tf-agents[reverb]) (1.17.2)
# Collecting typing-extensions==4.5.0 (from tf-agents[reverb])
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pygame==2.1.3 (from tf-agents[reverb])
#   Using cached pygame-2.1.3.tar.gz (12.8 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#
#
#       WARNING, No "Setup" File Exists, Running "buildconfig/config.py"
#       Using UNIX configuration...
#
#
#       Hunting dependencies...
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#       /bin/sh: 1: sdl2-config: not found
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/Compilation
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-eh6q_bkw/pygame_3f89ded70bfb4b89a058ae8b882c78c1/setup.py", line 400, in <module>
#           buildconfig.config.main(AUTO_CONFIG)
#         File "/tmp/pip-install-eh6q_bkw/pygame_3f89ded70bfb4b89a058ae8b882c78c1/buildconfig/config.py", line 231, in main
#           deps = CFG.main(**kwds, auto_config=auto)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-eh6q_bkw/pygame_3f89ded70bfb4b89a058ae8b882c78c1/buildconfig/config_unix.py", line 218, in main
#           DependencyProg('SDL', 'SDL_CONFIG', 'sdl2-config', '2.0', ['sdl']),
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-install-eh6q_bkw/pygame_3f89ded70bfb4b89a058ae8b882c78c1/buildconfig/config_unix.py", line 43, in __init__
#           self.ver = config[0].strip()
#                      ~~~~~~^^^
#       IndexError: list index out of range
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import tensorflow as tf
# from tf_agents.environments import suite_gym
# from tf_agents.environments import tf_py_environment
# from tf_agents.networks import q_network
# from tf_agents.agents.dqn import dqn_agent
# from tf_agents.replay_buffers import tf_uniform_replay_buffer
# from tf_agents.trajectories import trajectory
# from tf_agents.utils import common
import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
#Importamos el entorno del taxi
gym.make("Taxi-v3")

#Creamos el entorno
env = suite_gym.load('Taxi-v3')
train_env = tf_py_environment.TFPyEnvironment(env)
eval_env = tf_py_environment.TFPyEnvironment(env)

#Definimos la red neuronal (Q-Network)
q_net = q_network.QNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=(64, 64)
)

#Configuramos el agente DQN
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

agent = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net,
    optimizer=optimizer,
    td_errors_loss_fn=common.element_wise_squared_loss,
    train_step_counter=tf.Variable(0)
)

agent.initialize() #lo inicializamos

#Definimos el buffer de memoria (replay buffer)
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=10000
)

#Definimos la funcion para almacenar las transiciones
def collect_step(environment, policy, buffer):
    time_step = environment.current_time_step()
    action_step = policy.action(time_step)
    next_time_step = environment.step(action_step.action)
    traj = trajectory.from_transition(time_step, action_step, next_time_step)
    buffer.add_batch(traj)

# Funcion para entrenar
def train_agent():
    dataset = replay_buffer.as_dataset(
        num_parallel_calls=3,
        sample_batch_size=64,
        num_steps=2
    ).prefetch(3)

    iterator = iter(dataset)
    for _ in range(10):
        experience, _ = next(iterator)
        agent.train(experience)

#datos del entrenamiento
num_episodes = 100
rewards = []

# Entrenamiento
for episode in tqdm(range(num_episodes)):
    time_step = train_env.reset()
    episode_reward = 0

    while not time_step.is_last():
        collect_step(train_env, agent.collect_policy, replay_buffer)  # POLÍTICA DE EXPLORACIÓN
        time_step = train_env.current_time_step()
        episode_reward += time_step.reward.numpy()[0]

        # Entrenar el agente
        if replay_buffer.num_frames() > 64:
            train_agent()

    print(f"Episode {episode + 1}: Recompensa -> {episode_reward}")
    rewards.append(episode_reward)

#Mostramos los resultados
df_rewards = pd.DataFrame(rewards, columns=["Recompensa"])

print (df_rewards)

df_rewards = pd.DataFrame(rewards, columns=["Recompensa"])

# Graficar las recompensas por episodio
plt.figure(figsize=(10, 5))
plt.plot(df_rewards.index, df_rewards["Recompensa"])
plt.xlabel("Episodio")
plt.ylabel("Recompensa")
plt.title("Recompensa por Episodio en Taxi-v3")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 gym.make("Taxi-v3")
#       4 #Creamos el entorno
# ----> 5 env = suite_gym.load('Taxi-v3')
#       6 train_env = tf_py_environment.TFPyEnvironment(env)
#       7 eval_env = tf_py_environment.TFPyEnvironment(env)
#
# NameError: name 'suite_gym' is not defined

# %%
git clone https://github.com/keiohta/tf2rl.git tf2rl
cd tf2rl
# !pip install .
# Out:
#   Cell In[9], line 1
#     git clone https://github.com/keiohta/tf2rl.git tf2rl
#         ^
# SyntaxError: invalid syntax
